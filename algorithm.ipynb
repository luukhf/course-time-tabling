# %%
# %run Programming_project_cleaning_and_formatting.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 243
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student ID        244 non-null    object
#  1   Credits Required  244 non-null    int64
#  2   8                 244 non-null    object
#  3   7                 244 non-null    object
#  4   6                 244 non-null    object
#  5   5                 244 non-null    object
#  6   4                 244 non-null    object
#  7   3                 244 non-null    object
#  8   2                 244 non-null    object
#  9   1                 244 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 21.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 0 to 45
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Course ID     46 non-null     object
# ...

# %%
df_students
# Out:
# 0   Student ID  Credits Required        8        7      6      5      4  \
# 0          s_3                 3    DA707    DA512  DA302  DA702  DA714
# 1          s_4                 3    DA212    DA912  DA512  DA605  DA714
# 2          s_5                 3    DA104    DA803  DA217  DA306  DA311
# 3          s_6                 3    DA912  DA301-1  DA803  DA717  DA104
# 4          s_7                 3  DA910-2    DA212  DA104  DA302  DA311
# ..         ...               ...      ...      ...    ...    ...    ...
# 239      s_242                 3    DA207    DA408  DA912  DA714  DA803
# 240      s_243                 3    DA806    DA010  DA302  DA605  DA217
# 241      s_244                 3    DA104    DA311  DA605  DA717  DA201
# 242      s_245                 2    DA717    DA408  DA511  DA912  DA513
# 243      s_246                 3    DA104    DA912  DA206  DA803  DA512
#
# 0         3        2       1
# 0    DA415F  DA910-2   DA311
# 1     DA302    DA104   DA311
# ...

# %%
df_courses.head()
# Out:
# 0 Course ID  Min Students  Max Students  Time Slot  Credits
# 0     DA010             5            20          2        1
# 1     DA011             5            20          0        1
# 2    DA011F            10            24          3        1
# 3     DA104             5            20          9        1
# 4     DA201             5            20          1        2

# %% [markdown]
# ## This will become the algorithm
